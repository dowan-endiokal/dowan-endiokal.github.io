# %%
import pandas as pd
import duckdb
# %load_ext sql
# %config SqlMagic.displaylimit = None
con = duckdb.connect("../database/social-buzz.db")
# %sql con --alias duckdb
# Out:
# displaylimit: Value None will be treated as 0 (no limit)

# %%
# %%sql
# -- export data from source into database
# CREATE TABLE content AS
# SELECT * FROM read_csv("../raw-data/Content.csv", header = true);
#
# CREATE TABLE reactions AS
# SELECT * FROM read_csv("../raw-data/Reactions.csv", header = true);
#
# CREATE TABLE reaction_type AS
# SELECT * FROM read_csv("../raw-data/ReactionTypes.csv", header = true);
# Out:
# Running query in 'duckdb'
# +-------+
# | Count |
# +-------+
# |   16  |
# +-------+

# %% [markdown]
# Start data cleaning for each table

# %%
# %%sql
# describe content;
# Out:
# Running query in 'duckdb'
# +-------------+-------------+------+------+---------+-------+
# | column_name | column_type | null | key  | default | extra |
# +-------------+-------------+------+------+---------+-------+
# |   column0   |    BIGINT   | YES  | None |   None  |  None |
# |  Content ID |   VARCHAR   | YES  | None |   None  |  None |
# |   User ID   |   VARCHAR   | YES  | None |   None  |  None |
# |     Type    |   VARCHAR   | YES  | None |   None  |  None |
# |   Category  |   VARCHAR   | YES  | None |   None  |  None |
# |     URL     |   VARCHAR   | YES  | None |   None  |  None |
# +-------------+-------------+------+------+---------+-------+

# %%
# %%sql
# -- standardise fields name
# ALTER TABLE content
# RENAME COLUMN "Content ID" TO content_id;
#
# ALTER TABLE content
# RENAME COLUMN "User ID" to user_id;
#
# ALTER TABLE content
# RENAME COLUMN Type to content_type;
#
# ALTER TABLE content
# RENAME COLUMN Category to category;
#
# ALTER TABLE content
# RENAME COLUMN URL to url;
# Out:
# Running query in 'duckdb'
# +---------+
# | Success |
# +---------+
# +---------+

# %%
# %%sql
# describe content
# Out:
# Running query in 'duckdb'
# +--------------+-------------+------+------+---------+-------+
# | column_name  | column_type | null | key  | default | extra |
# +--------------+-------------+------+------+---------+-------+
# |   column0    |    BIGINT   | YES  | None |   None  |  None |
# |  content_id  |   VARCHAR   | YES  | None |   None  |  None |
# |   user_id    |   VARCHAR   | YES  | None |   None  |  None |
# | content_type |   VARCHAR   | YES  | None |   None  |  None |
# |   category   |   VARCHAR   | YES  | None |   None  |  None |
# |     url      |   VARCHAR   | YES  | None |   None  |  None |
# +--------------+-------------+------+------+---------+-------+

# %%
# %%sql
# -- check for null values
# SELECT *
# FROM content
# WHERE column0 ISNULL
#     OR content_id ISNULL
#     OR user_id ISNULL
#     OR content_type ISNULL
#     OR category ISNULL
#     OR url ISNULL;
# Out:
# Running query in 'duckdb'
# +---------+--------------------------------------+--------------------------------------+--------------+-------------------+------+
# | column0 |              content_id              |               user_id                | content_type |      category     | url  |
# +---------+--------------------------------------+--------------------------------------+--------------+-------------------+------+
# |    5    | cf1e8c1a-23eb-4426-9f58-002fb1b53e91 | 4607d7b0-3313-49b8-9f73-5b8227fc5b67 |     GIF      |      cooking      | None |
# |    10   | 5118e9c5-1377-4cc5-a486-65b35b7b7b76 | ef56931b-540b-4166-9090-73ae48ac8d97 |     GIF      |      science      | None |
# |    15   | 7ffd0a82-4a0a-4527-a4d6-e251b756bac7 | 425b7021-0409-4358-af39-2bff14197d0a |     GIF      |      fitness      | None |
# |    20   | baa2db00-81ba-4c34-b17d-dd950bfa133b | 2f112802-2501-45b5-a9d9-470cda6ef23e |     GIF      |       soccer      | None |
# |    25   | a4067fb5-3ba8-4f97-87c2-ddad5e4029c2 | e2377b94-f06a-49ed-a266-377c4b07e980 |     GIF      |        food       | None |
# |    30   | a2ff9bf2-1fa6-4001-9566-f597f8e754ef | f0ef81ec-85b1-4475-ae60-aa7d373088aa |    video     |        food       | None |
# |    35   | 07f88a73-aef2-45fd-8b5d-418e448b853d | 18c56602-937e-4ff3-bc6c-43f0b14212ca |     GIF      |      Animals      | None |
# |    40   | ab4c4756-1c50-4136-bad9-3216e01ffac2 | bfe23c39-f814-4282-b0f7-506cd8295b8a |    audio     |      fitness      | None |
# |    45   | ea1afba2-c0a8-4d0f-ac64-91fd7a126bbc | 49da0743-cb4d-4c84-b6a2-537bbe7256d1 |     GIF      |   healthy eating  | None |
# |    50   | 2d949603-6676-4402-900b-2c2c78315ea0 | 4baf648a-0ad5-412d-8250-5a0ff9289fbf |    audio     |     "culture"     | None |
# |    55   | 82145a60-013e-4d96-81a5-399af8618158 | 2ad548cd-a899-4992-972b-92cde9cea8f1 |    audio     |        food       | None |
# |    60   | 87349e5b-eda4-4ae6-94d7-c42b9c5f03e9 | 8fe167eb-3c69-459a-b32d-b030b942eab4 |     GIF      |   healthy eating  | None |
# |    65   | a55b215b-06c5-4ef3-ac14-7e1569c3ad2e | 1e571af5-1796-424c-b744-a925897d44a3 |     GIF      |     education     | None |
# |    70   | 409aa11d-5af3-4a70-9da1-482857f5835e | 7000ac2e-87a0-4e23-b342-5f150e03f9ef |     GIF      |      Fitness      | None |
# |    75   | 3724de8a-ec2f-4021-a3f1-605d551da9d0 | 72d2587e-8fae-4626-a73d-352e6465ba0f |    video     |      culture      | None |
# |    80   | 0adb9a94-210a-4e84-bca1-13db9452ff0e | f3eb7ee0-7788-43a0-9686-1c399260b17e |    video     |   healthy eating  | None |
# |    85   | 45dbce0a-dbd8-4c4d-a492-4f5b84850d5c | ed5e1675-94a8-482c-8b43-1b9bb71d0495 |    video     |        dogs       | None |
# |    90   | da527dd0-4b7d-40a2-9fc6-89ef7c91fd87 | 95023c1b-04b7-4efd-ab34-61a4a70bb9d8 |     GIF      |      culture      | None |
# |    95   | e18e10e9-ed2a-494b-b215-edce890b1df4 | 57617bf3-b7d0-49cb-8d88-7d8346656397 |    photo     |        food       | None |
# |   100   | c8b044a9-8427-4b41-bc61-7b549ab1626c | 64b33556-9ecf-4ebc-8b4c-f829ab1a4881 |    photo     |     "studying"    | None |
# |   105   | 62681a6c-fe82-4186-ba7d-0805ae5b95ed | dcc6000c-ba92-472c-8bc1-9e9ca30b475b |    audio     |      Veganism     | None |
# |   110   | 0f1fce4d-78a3-4e0e-8a7b-ebd5f97c305e | ad9f5c2f-aa30-4baf-b084-56b1a4b63b09 |    photo     |        dogs       | None |
# |   115   | e4466189-0b96-4cc4-9d7d-d0f27b982548 | bbe8f83c-af9c-4dab-b5fa-7925822e450d |     GIF      |     education     | None |
# |   120   | f01ec49c-3179-43bb-b127-2b1a73f34b06 | 6e98e5c2-b7d7-4915-bb20-d01a42d29dee |    photo     |      animals      | None |
# |   125   | 61e6650c-5068-4575-9aee-4217ef3dbdb1 | a81378a5-58de-4631-b2b1-3eca765f68c6 |     GIF      |       tennis      | None |
# |   130   | d706b190-216c-4103-9107-fb7304766d68 | cad2d54d-9555-4dfe-bfcd-7a584895a002 |    video     |      cooking      | None |
# |   135   | e51b00b8-49d4-4909-9f25-8e9a06e28728 | e74edcea-5db4-4412-a4ce-eb7c5adc314a |    video     |       soccer      | None |
# |   140   | 3a106d1f-3942-49d4-9358-417f33d760c6 | 6ecb39b1-8f85-44f1-b2f3-0cffcba4d731 |    photo     |      Fitness      | None |
# |   145   | e5f1a4c6-2b27-4c8b-ac9a-21bb6ef7c946 | d27670c9-f85e-43e0-80a7-122cba908f10 |    audio     |       soccer      | None |
# |   150   | 5651450a-d330-46e6-bac9-c7c7e7defaf2 | bf721d00-4fa1-44b1-834f-4730cd51aefa |    photo     |     "animals"     | None |
# |   155   | 0d3d0a35-f806-4536-8733-abf1f92763e2 | a6f003be-b0fd-4100-b4cc-f568a21b9745 |     GIF      |      studying     | None |
# |   160   | 2893a837-3157-4bbd-918f-adc93b60480a | 3d5f257e-556b-4e19-b127-977bc5c4daed |    photo     |   healthy eating  | None |
# |   165   | 27fffa3e-000d-4f29-9358-5b0d2280d18c | 9664d628-9163-4aae-94e0-311f3bdb2f11 |    video     |        dogs       | None |
# |   170   | bd810ca4-54cf-420e-afec-0214b870672e | c1e01541-7508-4712-a22c-0370f232a41e |    photo     |     technology    | None |
# |   175   | 2c0e1f1e-1af8-45b6-b8f2-9714358dd2ad | 31ff6616-c1dc-4b9a-8091-0b4d0cac25b1 |    audio     |       Travel      | None |
# |   180   | 3d02ae44-c8f2-4d2d-a64c-9355a4f46430 | 18421d97-6f86-4d21-a7b1-dcc57dd8be76 |     GIF      |      fitness      | None |
# |   185   | f0d1b3ed-f1dd-4a09-b17a-b0f241932fbb | 8f41c07f-db4f-44f3-ae81-1f99cee047eb |    audio     |      studying     | None |
# |   190   | 8bcb980c-6f36-484d-974f-30b3e8fcc251 | 0f1f6aef-b094-4b4d-b6b6-412ebc42c12b |    photo     |       travel      | None |
# |   195   | 229d5bad-c1e4-439c-8978-0efdcdfea4d1 | 47def058-01cc-478f-9830-eaddcccac633 |    audio     |        food       | None |
# |   200   | 48a824bf-e495-4333-8acf-c800947ec2cd | 69fcad9e-45a9-4189-b7e1-96b26c57c542 |    audio     |      "soccer"     | None |
# |   205   | 8b51c05c-a8a2-4a6c-b031-165fb7bac840 | 66663a0d-856f-487f-a2a2-258af21ab3e5 |    video     |        dogs       | None |
# |   210   | 429632b9-88c0-4163-a7ed-4272a04f7838 | 56b8948a-68bd-425f-b842-eabe6bcfacca |    audio     |      Animals      | None |
# |   215   | db672f6f-2f5b-47bd-aed6-bfc22188de4d | c834ba1d-8a10-4984-aaf2-7c2eab207076 |    audio     |       soccer      | None |
# |   220   | 1987b43d-bcb9-4ab0-8634-ef3623928e94 | 0828c4e1-63ec-4121-aa07-eefd37954bb9 |    photo     |     education     | None |
# |   225   | ad08dde0-ec5d-41ef-baed-10c6d66028aa | 84bd5adb-286c-429a-926d-4ea120270825 |     GIF      |     technology    | None |
# |   230   | b1c49557-0623-4fb2-8f22-1453286fedad | 54a8e072-5369-4122-9189-43b55e1a4ba2 |    video     |   healthy eating  | None |
# |   235   | 3dc03a86-f481-42fa-bf43-a7bcf3b6572e | 3af8d78b-55c4-4ac0-8161-7cc3f6ec11c
# |   650   | 9c8be342-6cff-4d80-bf94-fd0fd8ccd845 | b9480379-4b96-412c-8dca-96fff9ae81a3 |    video     |       "dogs"      | None |
# |   655   | 79dfc9a4-42c0-42a5-abe4-2b5d3b8a05ab | 334e2fe8-6f2c-424c-8ed5-12c99f048722 |     GIF      |      culture      | None |
# |   660   | e1792fe6-28e0-49fc-8b01-0e027461d8b5 | 6fb7ead6-71f3-4f57-94bd-18111fbc5e1a |     GIF      |     technology    | None |
# |   665   | 5a0b2edf-78dc-4c4f-ada9-464523b52f12 | ffdb3615-516c-422f-aa24-a137e3027d3a |    audio     |      Fitness      | None |
# |   670   | 18cb1ce7-fb66-4a56-8042-e38c9593ade1 | a58444bc-a23e-40a1-b09d-0f90bd5cd6b3 |    photo     |      animals      | None |
# |   675   | f9e9544e-16b5-416f-9aec-80a723d1e64c | 877ce8ba-564f-4b86-9cdc-94a93d9a7997 |    video     |      culture      | None |
# |   680   | 7cbe1ddf-f81e-4597-be11-420b4dd815dd | ba55c3a8-5ab2-486a-8c90-b972117453bb |     GIF      |     technology    | None |
# |   685   | e221de96-8536-4782-8281-f9cda62f3c81 | 48bed4d7-0329-472c-96d9-b23a103eb834 |    photo     |        food       | None |
# |   690   | 1287b5c5-604b-462b-bf77-e64a8e89739e | 2026ccb6-77b2-494c-9b6b-a5d32aa86776 |    photo     |      studying     | None |
# |   695   | c6616e7c-f815-46d0-9b1d-d7ea977f5d32 | 40e643fb-369c-4ecb-beb7-810114f331fa |    audio     |     technology    | None |
# |   700   | 2c043e74-63e2-472b-a31a-6ea060febfc1 | 7be6e8bc-39b0-4035-ac93-1df8fd7e1928 |     GIF      |     Education     | None |
# |   705   | 28fc1e6d-eae9-47de-af11-11ad726b2a88 | 3f2d07e5-3604-4873-9737-bb44340773d8 |    photo     |      cooking      | None |
# |   710   | bb6c0257-5d4d-4bb8-be58-4bd7ebd9c337 | 7d624010-a0e7-455b-a606-48c5c467dd80 |    video     |      animals      | None |
# |   715   | 3896723f-560c-4008-9635-e3ecf1e2b37c | f62c96d8-5b1e-45c6-8a65-b36a9387827d |    video     |      cooking      | None |
# |   720   | 45630f5a-78c1-46a1-bdc7-79cd11bb3c13 | 3956593b-7739-426a-b7a5-e841c95a5df9 |    photo     |       travel      | None |
# |   725   | dc1d4628-4edc-47c2-8da7-0b3d16ef5ddf | bf970f55-66c1-402d-a5d7-f086421516c9 |    video     |     technology    | None |
# |   730   | 6082eb46-c239-40f5-bfcd-fb72b823ee71 | fc17ca61-7c66-4ceb-8504-32f58b438b45 |    video     |   healthy eating  | None |
# |   735   | 279fdb2b-e9ca-4531-b55f-c8fe294083cd | 47def058-01cc-478f-9830-eaddcccac633 |    video     |   Healthy Eating  | None |
# |   740   | ee18c383-1e7a-4507-9e78-1061da09143a | 19fa2bc2-96ab-45b6-99de-1995c2bee330 |    audio     |     education     | None |
# |   745   | b15792cb-995f-473e-8372-5cbe88eb059b | a710ab29-b72a-42c8-a79b-42e63d4a8bfd |    photo     |       travel      | None |
# |   750   | b0782637-2604-40f7-8fc6-5e7d9ffd2255 | c1e01541-7508-4712-a22c-0370f232a41e |    video     |     "cooking"     | None |
# |   755   | 98169c04-79b1-4702-82af-ac0fa461e044 | b1ceae0c-016d-421f-a6f0-488a7857f9f6 |    photo     |        food       | None |
# |   760   | 01f310fc-5692-4cc1-a7bb-fc62977d79bb | eff1e86a-8ede-4a41-818b-9442e3181ee3 |    audio     |       tennis      | None |
# |   765   | 964a54b7-7dc7-40b0-bd94-9898b670f9cd | 15e325b1-c221-4bf8-8010-18d76b03646e |    photo     |      science      | None |
# |   770   | 6f48fe2b-7c20-4065-8ae9-7bea61275dc7 | 084eb113-0d87-4ae5-891b-2ec7f1e194a8 |     GIF      |      Science      | None |
# |   775   | e1eca98c-c5fd-4fe4-825f-2d36e8bd56f1 | e206e31b-5f85-4964-b6ea-d7ee5324def1 |    audio     |      veganism     | None |
# |   780   | 019b61f4-926c-438e-adaf-6119c5eab752 | 9a5c1dcc-d26b-4303-b487-3075e7d34e02 |    photo     |      fitness      | None |
# |   785   | 6aa06c00-d796-43c3-816d-70f21fe58f80 | 0a1cde57-79ab-4c61-b664-1d3b290b43cf |    audio     |      science      | None |
# |   790   | 4dd4da35-453e-466d-95ca-b1a7710fac1f | ad4bd878-55e7-487c-a4db-470b23bbd832 |     GIF      |     technology    | None |
# |   795   | 94f8ffbb-d888-4713-8cdd-ea57466d88b2 | cab84c6a-e342-43ab-85a1-9c6ac1e93bac |    video     |      science      | None |
# |   800   | e1eb9e92-2e08-48b0-8be7-a2a98048aa08 | 2dd186bb-7a28-4e80-99c7-f1936afc7b49 |    video     | "public speaking" | None |
# |   805   | 8b1bfacc-00fd-4f6e-b647-6ecfe2b7ce69 | 2a41e628-4cc5-4765-af2e-8b3dec750c0b |    photo     |      Science      | None |
# |   810   | 56b0b1ab-a07c-4379-b699-80ccc8689c85 | 4607d7b0-3313-49b8-9f73-5b8227fc5b67 |    video     |      culture      | None |
# |   815   | 990f1598-4dbb-403c-a5b2-48de2c30b1ca | c5d04879-87bd-4950-9e63-334382ef53af |    audio     |        food       | None |
# |   820   | c9082d3b-6f2b-4057-a0b8-3538a247982a | 7adafb3c-7c7c-492b-be5b-5ddd9ff1316a |     GIF      |   healthy eating  | None |
# |   825   | ae87a6a3-1a9e-4323-981d-b63c1f8ca2a6 | ce9b41f4-625e-4868-83d1-6b53767a8af5 |    audio     |        food       | None |
# |   830   | 0f1cb5c0-ac2a-4c8a-9fb9-115d60493247 | ce9b41f4-625e-4868-83d1-6b53767a8af5 |     GIF      |      veganism     | None |
# |   835   | abf9ec3b-1d0f-4238-a8f8-137072dab287 | 3af8d78b-55c4-4ac0-8161-7cc3f6ec11c9 |     GIF      |      veganism     | None |
# |   840   | b5966298-63d8-403e-96ab-9a610eb9752d | fe1c151b-1a95-43fa-9a4c-f3214adba852 |     GIF      |       Soccer      | None |
# |   845   | 41c97dd6-3f0d-4a6c-9083-2163e8e08e19 | 2c32ac39-926d-4473-801f-5733222ad74f |    video     |  public speaking  | None |
# |   850   | dd942c3f-2ed5-4849-9e2b-7484f5a4eaf4 | 89d6bd9d-ce6b-42e5-bb9b-ece3b338396d |    audio     |     "culture"     | None |
# |   960   | 16f8b629-5173-420f-9c8b-577313e9e128 | 600118fa-e6f4-4d74-aeb6-936abbbf38a1 |    video     |   healthy eating  | None |
# |   965   | f3e9785c-d4e0-4258-a876-4d58ddb38790 | de1d478e-3552-4223-b039-d3086cc485ec |     GIF      |      studying     | None |
# |   970   | c61b7ef6-d7ab-41fc-aebc-dc16f256957f | 41cd692a-be3c-4acd-a2c8-184586bdc180 |     GIF      |      cooking      | None |
# |   975   | 9c8f1389-d04e-4a55-a2f5-1612539b70a7 | 4edc3d1a-a7d9-4db6-89c3-f784d9954172 |    audio     |     technology    | None |
# |   980   | 54e29395-9eba-4945-abee-cad58cbab090 | ad9f5c2f-aa30-4baf-b084-56b1a4b63b09 |    video     |      Science      | None |
# |   985   | a973290c-989a-44d2-afb9-9b4bf16cc17f | 04e52602-e370-4a99-bfda-f0c1655058da |    video     |       tennis      | None |
# |   990   | 2e32de07-dc79-4cdc-bf1d-bac90ba3fd85 | ad4bd878-55e7-487c-a4db-470b23bbd832 |    video     |      studying     | None |
# |   995   | b4cef9ef-627b-41d7-a051-5961b0204ebb | 5b62e10e-3c19-4d28-a57c-e9bdc3d6758d |    video     |  public speaking  | None |
# +---------+--------------------------------------+--------------------------------------+--------------+-------------------+------+

# %%
# %%sql
# -- to check duplicate rows
# SELECT
#     content_id,
#     user_id,
#     COUNT(*) AS count
# FROM content
# WHERE url IS NOT NULL
# GROUP BY content_id, user_id
# HAVING COUNT(*) > 1;
# Out:
# Running query in 'duckdb'
# +------------+---------+-------+
# | content_id | user_id | count |
# +------------+---------+-------+
# +------------+---------+-------+

# %%
# %%sql
# SELECT DISTINCT content_type
# FROM content
# ORDER BY content_type;
# Out:
# Running query in 'duckdb'
# +--------------+
# | content_type |
# +--------------+
# |     GIF      |
# |    audio     |
# |    photo     |
# |    video     |
# +--------------+

# %%
# %%sql
# SELECT DISTINCT category
# FROM content
# ORDER BY category;
# Out:
# Running query in 'duckdb'
# +-------------------+
# |      category     |
# +-------------------+
# |     "animals"     |
# |     "cooking"     |
# |     "culture"     |
# |       "dogs"      |
# |       "food"      |
# | "public speaking" |
# |     "science"     |
# |      "soccer"     |
# |     "studying"    |
# |    "technology"   |
# |      "tennis"     |
# |     "veganism"    |
# |      Animals      |
# |      Culture      |
# |     Education     |
# |      Fitness      |
# |        Food       |
# |   Healthy Eating  |
# |  Public Speaking  |
# |      Science      |
# |       Soccer      |
# |      Studying     |
# |     Technology    |
# |       Travel      |
# |      Veganism     |
# |      animals      |
# |      cooking      |
# |      culture      |
# |        dogs       |
# |     education     |
# |      fitness      |
# |        food       |
# |   healthy eating  |
# |  public speaking  |
# |      science      |
# |       soccer      |
# |      studying     |
# |     technology    |
# |       tennis      |
# |       travel      |
# |      veganism     |
# +-------------------+

# %%
# %%sql
# -- select columns needed (content_id, content_type & category)
# SELECT
#     content_id,
#     content_type,
#     REPLACE(LOWER(category), '"', '') AS category
# FROM content
# LIMIT 20;
# Out:
# Running query in 'duckdb'
# +--------------------------------------+--------------+-----------------+
# |              content_id              | content_type |     category    |
# +--------------------------------------+--------------+-----------------+
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |    photo     |     studying    |
# | 9f737e0a-3cdd-4d29-9d24-753f4e3be810 |    photo     |  healthy eating |
# | 230c4e4d-70c3-461d-b42c-ec09396efb3f |    photo     |  healthy eating |
# | 356fff80-da4d-4785-9f43-bc1261031dc6 |    photo     |    technology   |
# | 01ab84dd-6364-4236-abbb-3f237db77180 |    video     |       food      |
# | cf1e8c1a-23eb-4426-9f58-002fb1b53e91 |     GIF      |     cooking     |
# | 3f8590c7-6ab2-4973-805a-90cdec355f05 |    video     |       dogs      |
# | e5490118-90d5-4572-ab1c-1fbc87b8d9ca |    video     |    technology   |
# | 0bedca96-fb76-4287-a83c-17330ed39cce |    photo     |      soccer     |
# | b18cb63f-4c8e-44ee-a47f-541e95191d11 |    photo     | public speaking |
# | 5118e9c5-1377-4cc5-a486-65b35b7b7b76 |     GIF      |     science     |
# | 46fb701d-6c26-458e-ada3-2ebe5dbba01f |    audio     | public speaking |
# | 0be59876-d70c-486c-8e0b-a06bef7a2cd6 |     GIF      |      tennis     |
# | 81abd65a-3b76-4574-a0a7-db6bf7184ae2 |    video     |       food      |
# | e6ee2244-9382-49a9-8cbf-fa54aaaa2392 |    audio     |      travel     |
# | 7ffd0a82-4a0a-4527-a4d6-e251b756bac7 |     GIF      |     fitness     |
# | f332d362-dc48-46c2-a64b-641157c0987e |     GIF      |      soccer     |
# | a2e93b29-9259-4092-a4d7-62d5e823bb74 |    video     | public speaking |
# | 9b3a6d30-48e8-476c-82be-9031524bd04d |    video     |       food      |
# | 850fe90d-47d6-4eb7-b9c8-810afcb99ce9 |    video     |      tennis     |
# +--------------------------------------+--------------+-----------------+

# %%
# %%sql
# --export to csv
# COPY (
# SELECT
#     content_id,
#     content_type,
#     REPLACE(LOWER(category), '"', '') AS category
# FROM content
# )
# TO "../data/clean/content-clean.csv" (HEADER, DELIMITER ',');
# Out:
# Running query in 'duckdb'
# +-------+
# | Count |
# +-------+
# |  1000 |
# +-------+

# %%
# %%sql
# describe reactions
# Out:
# Running query in 'duckdb'
# +-------------+-------------+------+------+---------+-------+
# | column_name | column_type | null | key  | default | extra |
# +-------------+-------------+------+------+---------+-------+
# |   column0   |    BIGINT   | YES  | None |   None  |  None |
# |  Content ID |   VARCHAR   | YES  | None |   None  |  None |
# |   User ID   |   VARCHAR   | YES  | None |   None  |  None |
# |     Type    |   VARCHAR   | YES  | None |   None  |  None |
# |   Datetime  |  TIMESTAMP  | YES  | None |   None  |  None |
# +-------------+-------------+------+------+---------+-------+

# %%
# %%sql
# -- to check duplicate rows
# SELECT
#     "Content ID" AS content_id,
#     "User ID" AS user_id,
#     Datetime AS datetime,
#     COUNT(*) AS count
# FROM reactions
# GROUP BY content_id, user_id, datetime
# HAVING COUNT(*) > 1;
# Out:
# Running query in 'duckdb'
# +------------+---------+----------+-------+
# | content_id | user_id | datetime | count |
# +------------+---------+----------+-------+
# +------------+---------+----------+-------+

# %%
# %%sql
# SELECT DISTINCT Type
# FROM reactions
# ORDER BY Type;
# Out:
# Running query in 'duckdb'
# +-------------+
# |     Type    |
# +-------------+
# |    adore    |
# |   cherish   |
# |   disgust   |
# |   dislike   |
# |     hate    |
# |    heart    |
# | indifferent |
# |  interested |
# |  intrigued  |
# |     like    |
# |     love    |
# |   peeking   |
# |    scared   |
# |  super love |
# |     want    |
# |   worried   |
# |     None    |
# +-------------+

# %%
# %%sql
# -- select columns needed (content_id, reaction_type & datetime)
# SELECT
#     "Content ID" AS content_id,
#     LOWER(Type) AS reaction_type,
#     Datetime AS datetime
# FROM reactions
# WHERE content_id IS NOT NULL
#     AND reaction_type IS NOT NULL
#     AND datetime IS NOT NULL
# LIMIT 20;
# Out:
# Running query in 'duckdb'
# +--------------------------------------+---------------+---------------------+
# |              content_id              | reaction_type |       datetime      |
# +--------------------------------------+---------------+---------------------+
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |    disgust    | 2020-11-07 09:43:50 |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |    dislike    | 2021-06-17 12:22:51 |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |     scared    | 2021-04-18 05:13:58 |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |    disgust    | 2021-01-06 19:13:01 |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |   interested  | 2020-08-23 12:25:58 |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |    peeking    | 2020-12-07 06:27:54 |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |    cherish    | 2021-04-11 17:35:49 |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |      hate     | 2021-01-27 08:32:09 |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |    peeking    | 2021-04-01 22:54:23 |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |      love     | 2020-08-04 05:05:02 |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |  indifferent  | 2020-11-07 08:36:27 |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |     scared    | 2020-11-02 06:28:53 |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |   interested  | 2020-11-01 01:16:21 |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |      hate     | 2020-10-07 18:39:08 |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |     scared    | 2020-09-03 18:51:38 |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |   super love  | 2021-02-24 05:09:23 |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |    peeking    | 2020-09-23 06:24:11 |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |  indifferent  | 2021-02-24 11:37:57 |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |   interested  | 2021-05-22 19:44:23 |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |   intrigued   | 2021-01-31 16:03:56 |
# +--------------------------------------+---------------+---------------------+

# %%
# %%sql
# --export to csv
# COPY (
# SELECT
#     "Content ID" AS content_id,
#     LOWER(Type) AS reaction_type,
#     Datetime AS datetime
# FROM reactions
# WHERE content_id IS NOT NULL
#     AND reaction_type IS NOT NULL
#     AND datetime IS NOT NULL
# )
# TO "../data/clean/reactions-clean.csv" (HEADER, DELIMITER ',');
# Out:
# Running query in 'duckdb'
# +-------+
# | Count |
# +-------+
# | 24573 |
# +-------+

# %%
# %%sql
# describe reaction_type
# Out:
# Running query in 'duckdb'
# +-------------+-------------+------+------+---------+-------+
# | column_name | column_type | null | key  | default | extra |
# +-------------+-------------+------+------+---------+-------+
# |   column0   |    BIGINT   | YES  | None |   None  |  None |
# |     Type    |   VARCHAR   | YES  | None |   None  |  None |
# |  Sentiment  |   VARCHAR   | YES  | None |   None  |  None |
# |    Score    |    BIGINT   | YES  | None |   None  |  None |
# +-------------+-------------+------+------+---------+-------+

# %%
# %%sql
# SELECT *
# FROM reaction_type
# ORDER BY Score DESC;
# Out:
# Running query in 'duckdb'
# +---------+-------------+-----------+-------+
# | column0 |     Type    | Sentiment | Score |
# +---------+-------------+-----------+-------+
# |    7    |  super love |  positive |   75  |
# |    9    |    adore    |  positive |   72  |
# |    1    |     want    |  positive |   70  |
# |    8    |   cherish   |  positive |   70  |
# |    6    |     love    |  positive |   65  |
# |    0    |    heart    |  positive |   60  |
# |    10   |     like    |  positive |   50  |
# |    12   |  intrigued  |  positive |   45  |
# |    13   |   peeking   |  neutral  |   35  |
# |    4    |  interested |  positive |   30  |
# |    5    | indifferent |  neutral  |   20  |
# |    14   |    scared   |  negative |   15  |
# |    15   |   worried   |  negative |   12  |
# |    11   |   dislike   |  negative |   10  |
# |    3    |     hate    |  negative |   5   |
# |    2    |   disgust   |  negative |   0   |
# +---------+-------------+-----------+-------+

# %%
# %%sql
# -- export to csv
# COPY (
# SELECT
#     Type AS reaction_type,
#     Sentiment AS sentiment,
#     Score AS score
# FROM reaction_type
# )
# TO "../data/clean/reaction-type-clean.csv" (HEADER, DELIMITER ',');
# Out:
# Running query in 'duckdb'
# +-------+
# | Count |
# +-------+
# |   16  |
# +-------+

# %%
# %%sql
# SELECT
#     r."Content ID" AS content_id,
#     LOWER(r.Type) AS reaction_type,
#     r.Datetime AS datetime,
#     c.content_type,
#     REPLACE(LOWER(c.category), '"', '') AS category
# FROM reactions r
# INNER JOIN content c ON r."Content ID" = c.content_id
# WHERE r."Content ID" IS NOT NULL
#     AND r.Type IS NOT NULL
#     AND r.Datetime IS NOT NULL
# LIMIT 20;
# Out:
# Running query in 'duckdb'
# +--------------------------------------+---------------+---------------------+--------------+----------+
# |              content_id              | reaction_type |       datetime      | content_type | category |
# +--------------------------------------+---------------+---------------------+--------------+----------+
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |    disgust    | 2020-11-07 09:43:50 |    photo     | studying |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |    dislike    | 2021-06-17 12:22:51 |    photo     | studying |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |     scared    | 2021-04-18 05:13:58 |    photo     | studying |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |    disgust    | 2021-01-06 19:13:01 |    photo     | studying |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |   interested  | 2020-08-23 12:25:58 |    photo     | studying |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |    peeking    | 2020-12-07 06:27:54 |    photo     | studying |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |    cherish    | 2021-04-11 17:35:49 |    photo     | studying |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |      hate     | 2021-01-27 08:32:09 |    photo     | studying |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |    peeking    | 2021-04-01 22:54:23 |    photo     | studying |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |      love     | 2020-08-04 05:05:02 |    photo     | studying |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |  indifferent  | 2020-11-07 08:36:27 |    photo     | studying |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |     scared    | 2020-11-02 06:28:53 |    photo     | studying |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |   interested  | 2020-11-01 01:16:21 |    photo     | studying |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |      hate     | 2020-10-07 18:39:08 |    photo     | studying |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |     scared    | 2020-09-03 18:51:38 |    photo     | studying |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |   super love  | 2021-02-24 05:09:23 |    photo     | studying |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |    peeking    | 2020-09-23 06:24:11 |    photo     | studying |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |  indifferent  | 2021-02-24 11:37:57 |    photo     | studying |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |   interested  | 2021-05-22 19:44:23 |    photo     | studying |
# | 97522e57-d9ab-4bd6-97bf-c24d952602d2 |   intrigued   | 2021-01-31 16:03:56 |    photo     | studying |
# +--------------------------------------+---------------+---------------------+--------------+----------+

# %%
# %%sql
# -- to get top 5 category
# SELECT
#     REPLACE(LOWER(c.category), '"', '') AS category,
#     SUM(rt.Score) AS total_score
# FROM
#     reactions r
#     INNER JOIN content c ON r."Content ID" = c.content_id
#     INNER JOIN reaction_type rt ON r.Type = rt.Type
# WHERE
#     r."Content ID" IS NOT NULL
#     AND r.Type IS NOT NULL
#     AND r.Datetime IS NOT NULL
# GROUP BY category
# ORDER BY total_score DESC
# LIMIT 5;
# Out:
# Running query in 'duckdb'
# +----------------+-------------+
# |    category    | total_score |
# +----------------+-------------+
# |    animals     |    69548    |
# | healthy eating |    69067    |
# |   technology   |    67472    |
# |    science     |    66043    |
# |    cooking     |    63982    |
# +----------------+-------------+

# %%
# %%sql
# -- to combine into a singular table
# WITH category_scores AS (
#     SELECT
#         REPLACE(LOWER(c.category), '"', '') AS category,
#         SUM(rt.Score) AS total_score
#     FROM
#         reactions r
#         INNER JOIN content c ON r."Content ID" = c.content_id
#         INNER JOIN reaction_type rt ON r.Type = rt.Type
#     WHERE
#         r."Content ID" IS NOT NULL
#         AND r.Type IS NOT NULL
#         AND r.Datetime IS NOT NULL
#     GROUP BY
#         category
#     ORDER BY
#         total_score
# )
#
# SELECT
#     r."Content ID" AS content_id,
#     LOWER(r.Type) AS reaction_type,
#     r.Datetime AS datetime,
#     c.content_type,
#     REPLACE(LOWER(c.category), '"', '') AS category,
#     rt.Sentiment AS sentiment,
#     rt.Score AS score,
#     cs.total_score
# FROM
#     reactions r
#     INNER JOIN content c ON r."Content ID" = c.content_id
#     INNER JOIN reaction_type rt ON r.Type = rt.Type
#     LEFT JOIN category_scores cs ON REPLACE(LOWER(c.category), '"', '') = cs.category
# WHERE
#     r."Content ID" IS NOT NULL
#     AND r.Type IS NOT NULL
#     AND r.Datetime IS NOT NULL
# ORDER BY cs.total_score DESC
# LIMIT 10;
# Out:
# Running query in 'duckdb'
# +--------------------------------------+---------------+---------------------+--------------+----------+-----------+-------+-------------+
# |              content_id              | reaction_type |       datetime      | content_type | category | sentiment | score | total_score |
# +--------------------------------------+---------------+---------------------+--------------+----------+-----------+-------+-------------+
# | 07f88a73-aef2-45fd-8b5d-418e448b853d |    cherish    | 2021-03-12 16:22:28 |     GIF      | animals  |  positive |   70  |    69548    |
# | 07f88a73-aef2-45fd-8b5d-418e448b853d |   intrigued   | 2020-10-17 10:20:24 |     GIF      | animals  |  positive |   45  |    69548    |
# | 07f88a73-aef2-45fd-8b5d-418e448b853d |      like     | 2020-12-19 16:42:35 |     GIF      | animals  |  positive |   50  |    69548    |
# | 07f88a73-aef2-45fd-8b5d-418e448b853d |      love     | 2021-05-31 05:46:59 |     GIF      | animals  |  positive |   65  |    69548    |
# | 07f88a73-aef2-45fd-8b5d-418e448b853d |      hate     | 2020-12-27 03:37:01 |     GIF      | animals  |  negative |   5   |    69548    |
# | 07f88a73-aef2-45fd-8b5d-418e448b853d |     scared    | 2021-05-24 20:32:26 |     GIF      | animals  |  negative |   15  |    69548    |
# | 07f88a73-aef2-45fd-8b5d-418e448b853d |      hate     | 2021-01-19 22:28:57 |     GIF      | animals  |  negative |   5   |    69548    |
# | 07f88a73-aef2-45fd-8b5d-418e448b853d |    cherish    | 2021-03-02 14:45:28 |     GIF      | animals  |  positive |   70  |    69548    |
# | 07f88a73-aef2-45fd-8b5d-418e448b853d |     adore     | 2021-02-12 16:37:09 |     GIF      | animals  |  positive |   72  |    69548    |
# | 4fa14453-7b29-4302-b51f-9aa23b472c1b |    cherish    | 2021-04-18 19:52:53 |    audio     | animals  |  positive |   70  |    69548    |
# +--------------------------------------+---------------+---------------------+--------------+----------+-----------+-------+-------------+

# %%
# %%sql
# -- export to csv
# COPY (
# WITH category_scores AS (
#     SELECT
#         REPLACE(LOWER(c.category), '"', '') AS category,
#         SUM(rt.Score) AS total_score
#     FROM
#         reactions r
#         INNER JOIN content c ON r."Content ID" = c.content_id
#         INNER JOIN reaction_type rt ON r.Type = rt.Type
#     WHERE
#         r."Content ID" IS NOT NULL
#         AND r.Type IS NOT NULL
#         AND r.Datetime IS NOT NULL
#     GROUP BY
#         category
#     ORDER BY
#         total_score
# )
#
# SELECT
#     r."Content ID" AS content_id,
#     LOWER(r.Type) AS reaction_type,
#     r.Datetime AS datetime,
#     c.content_type,
#     REPLACE(LOWER(c.category), '"', '') AS category,
#     rt.Sentiment AS sentiment,
#     rt.Score AS score,
#     cs.total_score
# FROM
#     reactions r
#     INNER JOIN content c ON r."Content ID" = c.content_id
#     INNER JOIN reaction_type rt ON r.Type = rt.Type
#     LEFT JOIN category_scores cs ON REPLACE(LOWER(c.category), '"', '') = cs.category
# WHERE
#     r."Content ID" IS NOT NULL
#     AND r.Type IS NOT NULL
#     AND r.Datetime IS NOT NULL
# ORDER BY cs.total_score DESC
# )
# TO "../data/clean/final-clean.csv" (HEADER, DELIMITER ',');
# Out:
# Running query in 'duckdb'
# +-------+
# | Count |
# +-------+
# | 61869 |
# +-------+
